# %% [markdown]
# # Taller 4

# %% [markdown]
#    ### Integrantes *Josafat Choque - Nicolas Hernandez*
#    ### Carreras ICEL - ICI-B
#    ### Profesora a cargo *Dr. Darlin Soto*

# %% [markdown]
# ## Obtención de información
# La **base de datos** corresponde a la encuesta de Caracterización Socioeconómica Nacional (Casen) cuyo objetivo es recoletar información que permita:
#  - Conocer periódicamente la situación de los hogares y de la población, especialmente de aquella en situación de pobreza y de aquellos grupos definidos como prioritarios por la política social, con relación a aspectos demográficos, de educación, salud, vivienda, trabajo e ingresos. En particular, estimar la magnitud de la pobreza y la distribución del ingreso; identificar carencias y demandas de la población en las áreas señaladas; y evaluar las distintas brechas que separan a los diferentes segmentos sociales y ámbitos territoriales.
#  - Evaluar el impacto de la política social: estimar la cobertura, la focalización y la distribución del gasto fiscal de los principales programas sociales de alcance nacional entre los hogares, según su nivel de ingreso, para evaluar el impacto de este gasto en el ingreso de los hogares y en la distribución del mismo.
#
# **Su objeto de estudio** *son los hogares que habitan las viviendas particulares que se ubican en el territorio nacional*, exceptuando algunas zonas muy alejadas o de difícil acceso, así como las personas que forman parte de esos hogares.
#
# ### Enlace
# La base de datos y el libro de variables se obtuvieron de la página web del Ministerio de Desarrollo Social y Familia: https://observatorio.ministeriodesarrollosocial.gob.cl/encuesta-casen-2017.
# Durante junio del 2023.

# %% [markdown]
# # Análsis de datos
#
# ## Preguntas objetivo

# %% [markdown]
# 1)	¿Cómo se distribuye la cantidad de hijos nacidos en la población de muestra? (s4)
#
# 2)	¿Existe diferencia significativas en la distribución de las personas han tenido otro trabajo aparte de su trabajo principal y si han tenido hijos o no? (o26,s4)
#
# 3)	¿Cómo es la distribución de la edad de las personas al tener su primer hijo? (s5)
#
# 4)	¿Cuál es el número de personas que tenían 20 años o menos al tener su primer hijo vivo y si se ha realizado una mamografía en los últimos 3 años? (s5,s10)
#
# 5)	¿Cómo se distribuye el área de las viviendas de las personas encuestadas, comparando si terminaron Educación Media Científico-Humanista vs si terminaron su Educación Profesional Completa? (v12,e6a)
#
# 6)	¿Cómo se distribuyen las personas que realizaron la compra de su casa con Crédito Hipotecario por sexos?(v16,sexo)
#
# 7)	¿Entre qué años los encuestados adquirieron con más frecuencia su casa? (v14)
#
# 8)	¿Cómo se distribuye la cantiada de personas en el horgar de los encuestados? (numper)
#
# 9)	¿Las personas que pertenecen a un sindicato tienden a tener nivel educacional mayor? (o24a, e6a)
#
# 10)	¿Los hogares de pesonas cuya calefacción a base de carbón, es de gran número de inegrantes? (v36, numper)
#
# 11)	¿Las personas se van de la comuna en que nacieron? (r1b)

# %% [markdown]
# ### Descripción de variables
# Variable|Definición|Descripción|Datos Faltantes
# :-|:-|:-|:-
# o26|En el último mes, ¿tuvo otros trabajos además de su trabajo principal?|Variable cualitativa nominal, sus respuesta se categorizan en Si (1) y No (2) | 57.3%
# s4|¿Cuántos hijos nacidos vivos ha tenido en su vida?|Variable cuantitativa discreta, donde la cifra 99 es No sabe/No responde| 61.8%
# s5|¿Qué edad tenía cuando nació su primer hijo?|Variable cuantitativa continua, donde la cifra 99 es No sabe/No responde| 61.8%
# s10|En los últimos tres años, ¿Se ha hecho una mamografía?|Variable culitativa nominal, las respuestas se categorizan en Sí, durante el último año (1), Sí, hace más de un año y hasta 2 años (2), Sí, hace más de 2 años y hasta 3 años (3), No (4) y No sabe/No recuerda (9) | 71.5%
# v12|¿Cuántos metros cuadrados tiene la vivienda? |Variable cualitatita ordinal, donde las respuestas se categorizan por Menos de 30 m2 (1), De 30 a 40 m2 (2), De 41 a 60 m2 (3), De 61 a 100 m2 (4), De 101 a 150 m2 (5), Más de 150 m2(6) y No sabe/no responde (9)| No hay datos faltantes
# e6a|¿Cuál fue el nivel educacional más alto alcanzado o el nivel educacional actual?| Variable cualitativa ordinal, se categoriza en Nunca asistió (1),Sala cuna (2), Jardín Infantil (Medio menor y Medio mayor) (3), Prekinder/Kinder (Transición menor y Transición Mayor) (4), Educación Especial (Diferencial) (5), Primaria o Preparatoria (Sistema antiguo) (6), Educación Básica (7), Humanidades (Sistema Antiguo) (8), Educación Media Científico-Humanista (9), Técnica, Comercial, Industrial o Normalista (Sistema Antiguo) (10), Educación Media Técnica Profesional (11), Técnico Nivel Superior Incompleto (Carreras 1 a 3 años) (12), Técnico Nivel Superior Completo (Carreras 1 a 3 años) (13), Profesional Incompleto (Carreras 4 o más años) (14), Profesional Completo (Carreras 4 o más años) (15), Postgrado Incompleto (16), Postgrado Completo (17), No sabe/no responde (99)| No hay datos faltantes
# v14|¿En qué año compró o recibió la vivienda o el subsidio?|Variable cuantitativa continua, donde la cifra 9999 es No sabe/No responde|36.75%
# v16|¿Compró la vivienda con crédito hipotecario? |Variable cualitativa nominal, que categoriza sus respuestas en Sí, SERVIU (sólo viviendas adquiridas desde 1977 hasta 2001) (1), Sí, Banco Estado (2), Sí, banco privado (3), Sí, cooperativa (4), Sí, financiera u otra institución (5), No, sin crédito hipotecario (6) y No save/No responde (9)| 61.6%
# o24a|¿En su empleo principal, pertenece a Sindicato?|Variable cualitativa nominal, sus respuestas se categorizan en Sí (1), No (2) y No sabe (9)| 57.3%
# v36b|¿Qué combustible usa habitualmente para…: Calefacción |Variable cualitativa nominal, sus resuestas se categorizan en Gas licuado (cilindro) (1), Gas por red (de cañería) (2), Parafina o petróleo (3), Leña o derivados (pellets, astillas o briquetas) (4), Carbón (5), Electricidad (6), Energía solar (7) No usa combustible o fuente de energía (8), No tiene sistema (9) y No sabe/No responde (99)| No hay datos faltantes
# numper|Número de personas en el hogar |Variable cuantitativa discretra, obtiene resultados acotados desde 1 hasta 19|0.1%
# r1b|Cuando usted nació, ¿en qué comuna o país vivía su madre? |Variable cualitativa nominal, las respuestas se categorizan  en En esta comuna (1), En otra comuna de Chile. Especifique comuna (2), En otro país. Especifique país (3), No sabe (9)| No hay datos faltantes
# sexo|Sexo|Variable culitativa nominal, sus respuestas se categorizan en Hombre (1) y Mujer (2)|No hay datos faltantes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")  
import pyreadstat

# %%
# Leer el archivo .sav
archivo_sav = "Casen_2017.sav"
casen, metadatos = pyreadstat.read_sav(archivo_sav)

# %% [markdown]
# ## Validación de Información

# %%
casen.info() ## se valida información
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216439 entries, 0 to 216438
# Columns: 804 entries, folio to pobreza_multi_5d
# dtypes: float64(768), object(36)
# memory usage: 1.3+ GB

# %% [markdown]
# Se observan las variables 804  y 216439 observaciones.

# %% [markdown]
# ## Preguntas, análisis y respuestas

# %% [markdown]
# 1)	¿Cómo se distribuye la cantidad de hijos nacidos en la población de muestra?(s4)
# Se filtra la variable s4, para evitar que se muestre el valor 99, pues este dato no hace referencia a una cantidad de hijos nacidos.

# %%
casen_nacidos=casen[casen['s4']<80]
print("Resumen de 5 números de la variable s4")
print("-"*40)
print(casen_nacidos['s4'].describe())
plt.figure(figsize=(4,4))
sns.boxplot(x=casen_nacidos['s4'])
plt.title('Diagrama de caja de "La cantidad de hijos nacidos vivos"',y=1.01)
plt.xlabel('n° de hijos')
plt.show()
# Out:
# Resumen de 5 números de la variable s4
# ----------------------------------------
# count    181204.00000
# mean          1.77719
# std           1.90405
# min           0.00000
# 25%           0.00000
# 50%           2.00000
# 75%           3.00000
# max          22.00000
# Name: s4, dtype: float64

# %% [markdown]
# Se observa que el promedio es de 1.777 hijos, cercano a 2 hijos, además, que la mediana se encuentra en 2 hijos. A su vez, se observa la existencia de datos atípicos, incluso hay personas que han tenido más de 20 hijos.

# %% [markdown]
# **Respuestas:** Se tiene que la distribución es más densa entre 0 y 3 hijos, con una desviación estandar de 1.9 hijos y un rango de 22 hijos.

# %% [markdown]
# 2)	¿Existe diferencia significativas en la distribución de las personas que han tenido otro trabajo, o no, aparte de su trabajo principal (o26), según el número de hijos que han tenido (s4)?

# %%
plt.figure(figsize=(10,4))
count_plot = sns.countplot(x = casen.s4, hue = casen.o26)
plt.title('Gráfico de barras para "La cantidad de hijos nacidos vivos" por "Haber tenido un trabajo aparte del principal"',y=1.01)
plt.ylabel('n° de personas')
plt.xlabel('n° de hijos')
plt.show()

# %% [markdown]
# Del gráfico se **interpreta** que hay más personas que no han tenido trabajo extra, la mayor cantidad de respuestas se dan en personas que han tenido entre 0 y 3 hijos, disminuyendo significativamente desde 4 hijos en adelante.

# %% [markdown]
# **Respuesta:** No se observa una diferencia significativa en la tendencia de la distribución, pues sucede que tanto las personas que han tenido un trabajo extra como las que no, aumentan o disminuyen de la misma forma con la cantidad de hijos.

# %% [markdown]
# 3)	¿Cómo es la distribución de la edad de las personas al tener su primer hijo? (s5)  (Variable a usar s5 filtrada, pues 99 no es un dato que entregue una edad)

# %%
casen_edad_n=casen[casen['s5']<90]

print("Resumen de 5 números de la variable s5")
print("-"*40)
print(casen_edad_n['s5'].describe())

plt.figure(figsize=(8,4))
plot = plt.hist(casen_edad_n.s5, bins = 15,density=False,edgecolor = 'black') # bins corresponde al num de segmentos
plt.title('Histograma de "La Edad a la que tuvo a su primer hijo"',y=1.01)
plt.ylabel('n° de personas por cada segmento')
plt.xlabel('Edad')
plt.show()
# Out:
# Resumen de 5 números de la variable s5
# ----------------------------------------
# count    116169.000000
# mean         23.596794
# std           5.807876
# min          11.000000
# 25%          19.000000
# 50%          23.000000
# 75%          27.000000
# max          65.000000
# Name: s5, dtype: float64

# %% [markdown]
# Del histrograma se **interpreta** que los datos estan concentrados en la edad de 20 años y un par más, y que sobre los 40 años son muy pocas las personas que tienen su primer hijo.

# %% [markdown]
# **Respuesta:** Se observa que el promedio está cercano a la mediana, 23.6 y 23 años respectivamente, y que la mayor cantidad de datos se encuentran entre 19 y 27 años aproximadamente.

# %% [markdown]
# 4)	¿Cuál es el número de personas que tenían 20 años o menos al tener su primer hijo vivo (s5) y si se ha realizado una mamografía en los últimos 3 años (s10)?

# %%
casen_edad_n=casen[casen['s5']<=20]
casen_mamog_si=casen[casen['s10']<=3]
print('*' * 20, "Tabla de frecuencia de las variables s10 vs s5", '*' * 20)
tabla1=pd.crosstab(casen_edad_n['s5'],casen_mamog_si['s10'],margins=True,margins_name='Suma')
print(tabla1)
# Out:
# ******************** Tabla de frecuencia de las variables s10 vs s5 ********************
# s10    1.0   2.0   3.0   Suma
# s5
# 12.0    27    13     4     44
# 13.0    76    32    24    132
# 14.0   209    84    55    348
# 15.0   442   188   111    741
# 16.0   702   326   197   1225
# 17.0  1138   508   300   1946
# 18.0  1556   604   393   2553
# 19.0  1560   704   422   2686
# 20.0  1739   743   402   2884
# Suma  7449  3202  1908  12559

# %% [markdown]
# **Respuesta:** Mediante el filtrado y el uso de una tabla de frecuencias cruzadas se llega a que el total es de 12559 personas.

# %% [markdown]
# 5)	¿Cómo se distribuye el área de las viviendas de las personas encuestadas (v12) comparando si terminaron Educación Media Cientifico-Humanista vs si terminaron su Educación Profesional Completa  (e6a)?

# %%
fig = plt.figure(figsize=(4, 8))

fig.subplots_adjust(hspace=0.4)
                   
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

casen_media=casen[casen['e6a']==9]
casen_pro=casen[casen['e6a']==12]

sns.countplot(x =casen_media['v12'], hue =casen_media['e6a'],ax=ax1)
ax1.set_title('Gráfico de barras para "Categorías de áreas de las vivendas" y "Educación Media C-H" ',y=1)
ax1.set_ylabel('n° de personas')
ax1.set_xlabel('Categorías de áreas de las vivienda')

sns.countplot(x =casen_pro['v12'], hue =casen_pro['e6a'],ax=ax2)
ax2.set_title('Gráfico de barras para "Categorías de áreas de las vivendas" y "Educación Profesional"',y=1)
ax2.set_ylabel('n° de personas')
ax2.set_xlabel('Categorías de áreas de las vivienda')

plt.show()

# %% [markdown]
# Se **interpreta** de los graficos que hay mayor cantidad de respuestas de personas que han terminado la educación media que las que han terminado la educación profesional, en propociones se observa similitud, sin embargo, se tiene que las personas profesionales aumentan en proporción el tamaño de su vivienda entre 61-100 metros cuadrados.

# %% [markdown]
# **Respuesta:** La distribución es muy similar, exceptuando el aumento proporcional de 61-100 metros cuadrados por parte de los y las profesionales.

# %% [markdown]
# 6)	¿Cómo se distribuyen las personas que realizaron la compra de su casa con crédito hipotecario (v16) por sexos (sexo)?

# %%
plt.figure(figsize=(4,4))
count_plot = sns.countplot(x =casen['v16'], hue =casen['sexo'])
plt.title('Gráfico de barras para "Compra de vivienda con Crédito Hipotecario" según "Tipo de Sexo" ',y=1.01)
plt.ylabel('n° de personas')
plt.xlabel('Categorías de respuestas')
plt.show()

# %% [markdown]
# Se **interpreta** del grafico que hay una mayor cantidad de respuestas femeninas en todas las respuestas, que muy pocas personas realizan su compra de vivienda con crédito hipotecario mediante una cooperatva o financiera u otra instituación y que la mayoria de las personas NO realiza la compra con un crédito hipotecario.

# %% [markdown]
# **Respuesta:** Se observa un comportamiento similar en la compra, o no, de su casa con crédito hipotecario según el sexo, a su vez, se observa que la mayoría de las personas no ha realizado tal compra.

# %% [markdown]
# 7)	¿Entre qué años los encuestados adquierieron con más frecuencia sus casas?(v14)
#
#  (v14 se filtra, pues 9999 no es un año en que se adquirió un casa, si no que hace referencia a las respuestas No sabe/No responde.)

# %%
casen_años_casa=casen[casen['v14']<3000]
print("Resumen de 5 números de la variable v14")
print("-"*40)
print(casen_años_casa['v14'].describe())

plt.figure(figsize=(10,4))
plot = plt.hist(casen_años_casa['v14'], bins = 40,density=False,edgecolor = 'black') # bins corresponde al num de segmentos
plt.title('Histograma del "Año en que adquirió su vivienda"',y=1.01)
plt.ylabel('n° de personas por cada segmento')
plt.xlabel('Año')
plt.show()
# Out:
# Resumen de 5 números de la variable v14
# ----------------------------------------
# count    134470.000000
# mean       1996.423775
# std          15.783477
# min        1900.000000
# 25%        1988.000000
# 50%        2000.000000
# 75%        2008.000000
# max        2018.000000
# Name: v14, dtype: float64

# %% [markdown]
# Se **interpreta** del histograma que la adquisición de casas de la muestra inició con alza desde 1960 hasta mediados del años 2000, donde bajó la cantidad de aquisiciones durante unos años, pero antes del 2010 volvió a aumentar. Además, la mayor densidad de adaquisición se encuentra cercano a 1990 hasta los años 2015 aproximadamente.

# %% [markdown]
# **Respuesta:** Entre los años 1990 y 2015 aproxiamadamente se observa un aumeto en la frecuencia de aquisición.

# %% [markdown]
# 8)	¿Cómo se distribuye la cantidad de personas en el horgar de los encuestados? (numper)

# %%
print("Resumen de 5 números de la variable numper")
print("-"*20)
print(casen.numper.describe())
plt.figure(figsize=(4,4))
sns.boxplot(x=casen.numper)
plt.title('Histograma de "Número de personas en el Hogar"',y=1.01)
plt.ylabel('n° de respuestas por segmento')
plt.xlabel('n° de personas')
plt.show()
# Out:
# Resumen de 5 números de la variable numper
# --------------------
# count    216231.000000
# mean          3.847455
# std           1.718492
# min           1.000000
# 25%           3.000000
# 50%           4.000000
# 75%           5.000000
# max          19.000000
# Name: numper, dtype: float64

# %% [markdown]
# Se **interpreta** del diagrama de caja que en la mayoría de los hogares cuenta con menos de 5 integrantes, estan bajo el tercer cuartil, y que existen datos atípicos que superan el número 10 y 15 integrantes.

# %% [markdown]
# **Respuesta:** La distribución de la cantidad de personas en los hogares se hace mayor entre 3 y 5 personas, con un promedio de 3.85 y una mediana de 4 personas.

# %% [markdown]
# 9)	¿Las personas que pertenecen a un sindicato tienden a tener nivel educacional superior o igual que la educación media? (o24a, e6a)

# %%
casen_sindi= casen[casen['o24a']==1]
plt.figure(figsize=(10,4))
count_plot = sns.countplot(x = casen_sindi.e6a, hue = casen_sindi.o24a)
plt.title('Gráfico de barras para "Nivel Educacional más alto obtenido" por "Sí, pertenece a un sindicato"',y=1.01)
plt.ylabel('n° de personas')
plt.xlabel('Nivel educacional')
plt.show()

# %% [markdown]
# Se **interpreta** del gráfico que la mayor cantidad de personas que participa en un sindicato son quienes terminaron su educación media, además, quienes no completaron su educación media son quienes menos participa.

# %% [markdown]
# **Respuesta:** Si, pero en especial quienes terminaron su eduación media son quienes más participan.

# %% [markdown]
# 10)	¿Los hogares de pesonas cuya calefacción es en base a carbón, es de gran número de inegrantes? (v36, numper)

# %%
casen_calefaccionleña=casen[casen['v36b']==5]
plt.figure(figsize=(10,4))
count_plot = sns.countplot(x = casen_calefaccionleña.numper, hue = casen_calefaccionleña.v36b)
plt.title('Gráfico de barras para "Número de personas en el Hogar" por "Tipo de calefacción: Carbón"',y=1.01)
plt.ylabel('n° de personas')
plt.xlabel('n° de personas en el hogar')
plt.show()

# %% [markdown]
# Se **interpreta** del gráfico de barras que el mayor uso de calefacción a carbón se da en hogares con 2 integrantes, además que disminuye significativamente en hogares con mayor a 6 integrantes.

# %% [markdown]
# **Respuesta:** No, la mayoría de los hogares se encuentran entre 2 y 4 integrates, siendo los hogares con 2 personas quiene más usan carbón como fuente de calefacción.

# %% [markdown]
# 11)	¿Las personas se van de la comuna en que nacieron? (r1b)

# %%
personas = casen['r1b'].value_counts()
desfase = (0.1,0.1,0.25,.3)

plt.figure(figsize=(4,4)) 
plt.pie(personas, labels=["En esta comuna","En otra comuna de Chile","En otro país", "No sabe"], autopct='%0.1f%%',explode=desfase)
plt.title('Distribución de "La comuna en donde vivía su madre cuando nació usted"',y=1.1)
plt.axis('equal')
plt.show()

# %% [markdown]
# Se **interpreta** mediante el gráfico que el 59,5% de las personas encuestadas se mantiene en la comuna donde nacieron, el 36.5% se va de la comuna y un porcentaje mínimo es de otro país o no sabe.

# %% [markdown]
# **Respuestas:** No, la mayoria de las personas encuestadas permanecen en la comuna donde nacieron.

# %% [markdown]
# # Anexo

# %% [markdown]
# ¿Es más probable terminar la carrera universitaria o, una completa esta última, terminar un postgrado? (e6a)
